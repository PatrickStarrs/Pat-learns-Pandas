# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
econ = pd.read_csv("Unemployment.csv")

# %%
econ.describe()
# Out:
#             FIPStxt  Rural_urban_continuum_code_2013  \
# count   3275.000000                      3219.000000
# mean   31336.829618                         4.938490
# std    16321.509704                         2.724553
# min        0.000000                         1.000000
# 25%    19022.000000                         2.000000
# 50%    30019.000000                         6.000000
# 75%    46100.000000                         7.000000
# max    72153.000000                         9.000000
#
#        Urban_influence_code_2013   Metro_2013  Unemployment_rate_2007  \
# count                3219.000000  3222.000000             3270.000000
# mean                    5.189811     0.382992                5.064098
# std                     3.506942     0.486192                2.124528
# min                     1.000000     0.000000                1.500000
# 25%                     2.000000     0.000000                3.700000
# ...

# %%
econ
# Out:
#       FIPStxt State                    Area_name  \
# 0           0    US                United States
# 1        1000    AL                      Alabama
# 2        1001    AL           Autauga County, AL
# 3        1003    AL           Baldwin County, AL
# 4        1005    AL           Barbour County, AL
# 5        1007    AL              Bibb County, AL
# 6        1009    AL            Blount County, AL
# 7        1011    AL           Bullock County, AL
# 8        1013    AL            Butler County, AL
# 9        1015    AL           Calhoun County, AL
# 10       1017    AL          Chambers County, AL
# 11       1019    AL          Cherokee County, AL
# 12       1021    AL           Chilton County, AL
# 13       1023    AL           Choctaw County, AL
# 14       1025    AL            Clarke County, AL
# 15       1027    AL              Clay County, AL
# 16       1029    AL          Cleburne County, AL
# 17       1031    AL            Coffee County, AL
# ...

# %%
# Enter state to find the data for the particular state 
State = econ[(econ['State'] == 'MI')]

# %%
State
# Out:
#       FIPStxt State                  Area_name  \
# 1256    26000    MI                   Michigan
# 1257    26001    MI          Alcona County, MI
# 1258    26003    MI           Alger County, MI
# 1259    26005    MI         Allegan County, MI
# 1260    26007    MI          Alpena County, MI
# 1261    26009    MI          Antrim County, MI
# 1262    26011    MI          Arenac County, MI
# 1263    26013    MI          Baraga County, MI
# 1264    26015    MI           Barry County, MI
# 1265    26017    MI             Bay County, MI
# 1266    26019    MI          Benzie County, MI
# 1267    26021    MI         Berrien County, MI
# 1268    26023    MI          Branch County, MI
# 1269    26025    MI         Calhoun County, MI
# 1270    26027    MI            Cass County, MI
# 1271    26029    MI      Charlevoix County, MI
# 1272    26031    MI       Cheboygan County, MI
# 1273    26033    MI        Chippewa County, MI
# 1274    26035    MI           Clare County, MI
# ...

# %%
State.describe()
# Out:
#            FIPStxt  Rural_urban_continuum_code_2013  \
# count    68.000000                        67.000000
# mean   1066.014706                         4.641791
# std      39.522332                         2.441445
# min    1000.000000                         1.000000
# 25%    1032.500000                         3.000000
# 50%    1066.000000                         4.000000
# 75%    1099.500000                         6.000000
# max    1133.000000                         9.000000
#
#        Urban_influence_code_2013  Metro_2013  Unemployment_rate_2007  \
# count                  67.000000   67.000000               68.000000
# mean                    4.388060    0.432836                4.886765
# std                     2.959091    0.499208                1.519417
# min                     1.000000    0.000000                2.600000
# 25%                     2.000000    0.000000                3.775000
# 50%                     4.000000    0.000000                4.500000
# ...

# %%
income = State['Median_Household_Income_2016']
